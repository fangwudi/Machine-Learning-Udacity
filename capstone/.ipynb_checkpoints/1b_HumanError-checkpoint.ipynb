# %%
basedir = '/root/JupyterNotebook/distracted_driver_detection/input'

# %%
import os
import cv2
import glob
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
status = ["safe driving",  " texting - right",  "phone - right",  "texting - left",  "phone - left",  
                  "operation radio", "drinking", "reaching behind", "hair and makeup", "talking"]

# %%
model_image_size = (480,640)

# %%
gen = ImageDataGenerator()

train_generator = gen.flow_from_directory(os.path.join(basedir, 'train'),  model_image_size, \
                            shuffle=True, batch_size=1, class_mode="categorical",save_to_dir=basedir+'/temp')
# Out:
# Found 20175 images belonging to 10 classes.

# %%
i = 0

# %%
x,y = next(train_generator)
x=x[0]
x=x.astype('uint8')
plt.figure(figsize=(9, 12))
plt.axis('off')
plt.imshow(x)

# %%
i +=1
print(i)
print(status[np.argmax(y)])
# Out:
# 100
# operation radio

# %% [markdown]
# # 错误汇总
# 7 张错误：
# 3个talking（C9） 误判为 2个safe(C0),1个不知道
# 2个safe(C0) 误判为1个talkingC9）,1个不知道
# 2个化妆(C8) 误判为2个不知道
